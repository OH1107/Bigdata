# %%
print("hello world!")
# Out:
# hello world!

# %%
a=3
b=10

# %%
b=100

# %%
a*b
# Out:
# 300

# %%
import numpy as np
np.random.rand(10,2)
# Out:
# array([[0.86730685, 0.44592414],
#        [0.77652666, 0.51960142],
#        [0.53916619, 0.06747107],
#        [0.38685933, 0.44962152],
#        [0.48375909, 0.05440368],
#        [0.08133729, 0.89383848],
#        [0.3211365 , 0.1253996 ],
#        [0.70567604, 0.12296889],
#        [0.03612816, 0.25297057],
#        [0.74000001, 0.72552506]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
iris = sns.load_dataset("iris")
sns.pairplot(iris)
plt.show()
